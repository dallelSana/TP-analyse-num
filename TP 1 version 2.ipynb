# %% [markdown]
# <h1><center> TP1 : Résolution de l'équation non linéaire f(x)=0</center></h1>

# %% [markdown]
# ## Nom: Dallel
#
# ## Prénom: Sana

# %% [markdown]
# ## Objectif:
# ### connaître les méthodes itératives suivantes:

# %% [markdown]
# <ul>
# <li>La méthode de la dichotomie </li>
# <li>La méthode de point fixe</li>
# <li>La méthode de newton</li>
# </ul>

# %% [markdown]
# ## Exercice N1:

# %% [markdown]
# ![ex1.png](attachment:ex1.png)

# %% [markdown]
# ## Réponse :

# %% [markdown]
# ### 1) * Déclaration de deux fonction p(x) et f(x)

# %%
def p(x): 
    return (x-1)**6 
def f(x):
    return x**6 - 6*x**5 + 15*x**4 - 20*x**3 + 15*x**2 - 6*x + 1.

print('p({})={}'.format(0.998,p(0.998)))
print('f({})={}'.format(0.998,f(0.998)))
# Out:
# p(0.998)=6.400000000000034e-17
# f(0.998)=1.7763568394002505e-15

# %% [markdown]
# ### Remarque:
# #### théoriquement ces deux fonctions sont identiques mais lorsqu'on choisit une valeur trés proche de 1 on trouve des résultats différents !!

# %% [markdown]
# ## * Evaluation p(x) et f(x) pour x allant de .998 à 1.002 en choisissant des pas de .0001

# %%
import numpy as np
print('Fonction réduite')
print('            ')
for i in np.arange(0.998, 1.002,0.0001): #Renvoie des valeurs régulièrement espacées. 
                                         #(start=0.998 , stop=1.002, step=0.0001)
    print('p(i)= ' ,p(i))#Remplacer x par la valeur de i puis le calculé dans la fonction
print('')
print('------------------------------------------')
print('')
print('Fonction developpée')
print('')
for i in np.arange(0.998, 1.002,0.0001):
    print('f(i)= ' ,f(i))
print('------------------------------------------')

print(p(i)==f(i)) #Pour démontrer que les deux fonctions ne donnent pa la même valeur
# Out:
# Fonction réduite
#
# p(i)=  6.400000000000034e-17
# p(i)=  4.70458810000019e-17
# p(i)=  3.40122240000027e-17
# p(i)=  2.4137569000002966e-17
# p(i)=  1.6777216000002883e-17
# p(i)=  1.139062500000259e-17
# p(i)=  7.52953600000219e-18
# p(i)=  4.826809000001757e-18
# p(i)=  2.985984000001342e-18
# p(i)=  1.771561000000975e-18
# p(i)=  1.0000000000006715e-18
# p(i)=  5.314410000004355e-19
# p(i)=  2.6214400000026335e-19
# p(i)=  1.1764900000014617e-19
# p(i)=  4.665600000007277e-20
# p(i)=  1.562500000003131e-20
# p(i)=  4.096000000010936e-21
# p(i)=  7.290000000027557e-22
# p(i)=  6.400000000038403e-23
# p(i)=  1.0000000000126618e-24
# p(i)=  1.1985091468012028e-94
# p(i)=  9.999999999860165e-25
# p(i)=  6.399999999953138e-23
# p(i)=  7.289999999962809e-22
# p(i)=  4.095999999983651e-21
# p(i)=  1.562499999994804e-20
# p(i)=  4.6655999999865574e-20
# p(i)=  1.1764899999969834e-19
# p(i)=  2.6214399999939023e-19
# p(i)=  5.314409999988621e-19
# p(i)=  9.99999999998007e-19
# p(i)=  1.7715609999966836e-18
# p(i)=  2.9859839999947116e-18
# p(i)=  4.826808999991864e-18
# p(i)=  7.52953599998786e-18
# p(i)=  1.1390624999982356e-17
# p(i)=  1.6777215999974943e-17
# p(i)=  2.4137568999965134e-17
# p(i)=  3.401222399995235e-17
# p(i)=  4.704588099993592e-17
# p(i)=  6.399999999991508e-17
#
# ------------------------------------------
#
# Fonction developpée
#
# f(i)=  1.7763568394002505e-15
# f(i)=  1.7763568394002505e-15
# f(i)=  0.0
# f(i)=  -2.6645352591003757e-15
# f(i)=  1.7763568394002505e-15
# f(i)=  0.0
# f(i)=  -1.7763568394002505e-15
# f(i)=  -8.881784197001252e-16
# f(i)=  1.7763568394002505e-15
# f(i)=  -3.552713678800501e-15
# f(i)=  0.0
# f(i)=  -2.6645352591003757e-15
# f(i)=  0.0
# f(i)=  0.0
# f(i)=  -1.7763568394002505e-15
# f(i)=  -8.881784197001252e-16
# f(i)=  0.0
# f(i)=  1.7763568394002505e-15
# f(i)=  -1.7763568394002505e-15
# f(i)=  2.6645352591003757e-15
# f(i)=  0.0
# f(i)=  -1.7763568394002505e-15
# f(i)=  -1.7763568394002505e-15
# f(i)=  -4.440892098500626e-15
# f(i)=  -1.7763568394002505e-15
# f(i)=  5.329070518200751e-15
# f(i)=  0.0
# f(i)=  -2.6645352591003757e-15
# f(i)=  1.7763568394002505e-15
# f(i)=  -3.552713678800501e-15
# f(i)=  -3.552713678800501e-15
# f(i)=  8.881784197001252e-16
# f(i)=  1.7763568394002505e-15
# f(i)=  -1.7763568394002505e-15
# f(i)=  0.0
# f(i)=  2.6645352591003757e-15
# f(i)=  0.0
# f(i)=  1.7763568394002505e-15
# f(i)=  0.0
# f(i)=  2.6645352591003757e-15
# f(i)=  1.7763568394002505e-15
# ------------------------------------------
# False

# %% [markdown]
# ## Remarque:
# ### On trouve une erreur lors de l'utilisation des valeurs réels : Il y'a un problème d'arrondissment

# %% [markdown]
# ## 2) Présentation graphique:

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(0.998, 1.002, 0.0001)
p = lambda x:(x-1)**6 #lambda prend à chaque fois la valeur de x et retourne la valeur de l'expression
fig = plt.figure(1, figsize=(15, 7))
plt.plot(x,p(x)) 
f = lambda x: x**6 - 6*x**5 + 15*x**4 - 20*x**3 + 15*x**2 - 6*x + 1
fig=plt.figure(1, figsize=(15 , 10))
plt.plot(x,f(x))
plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('Graphe1: Les fonction p(x) et f(x)')
plt.legend(('p(x)', 'f(x)'), loc='upper center', shadow=True)
plt.grid(True)   
plt.show()

# %% [markdown]
# ## Exercice N2:

# %% [markdown]
# ![ex2.png](attachment:ex2.png)

# %% [markdown]
# ## Réponse :

# %% [markdown]
# ### 1) On va appliquer la méthode de dichotomie ( méthode de bsection):
# ### Rappel:
#  Soit f une fonction  continue et strictement croissante sur [a,b], telle que f(a).f(b)<0. On sait que l'équation f(x)=0 admet une unique solution x sur [a,b].
#  f(x)=0
# <center>et $x_{0}=\left(\dfrac{a+b}{2}\right)$</center>

# %% [markdown]
# Cas1:   f(a).f($x_{0}) <0 $  --> $x_{0}$ >0

# %% [markdown]
# Cas2:   f(a).f($x_{0}) >0 $  --> $x_{0}$ <0

# %%
import matplotlib.pyplot as plt
from numpy import linspace
f=lambda x: x**3+x**2-3*x-3
T=linspace(-2,2,41)
plt.title("solution dans [-2:2] ");
plt.xlabel("x")
plt.ylabel ("f(x)")
plt.grid(True)
plt.plot(T,f(T))

# %% [markdown]
# ### Daprés le graph de $f$ il existe 3 solutions :
# - $\alpha_1 \in ]-2;-1.5[$
# - $\alpha_2 \in ]-1.5;-0.5[$
# - $\alpha_3 \in ]1.5;2[$

# %% [markdown]
# ## 2)

# %%
def dicho(a,b,f,eps):
    
    while (b-a)>eps:
        m=(a+b)/2
        if f(m)==0:
            return m
        if f(a)*f(m)<0 :
            b=m
        else :
            a=m
    return m

# %%
f=lambda x: x**3+x**2-3*x-3
dicho(-2,-1.5,f,0.001)
# Out:
# -1.7314453125

# %% [markdown]
# ## 3)

# %%
def dichow(a,b,f,eps):
    cp=0
    while (b-a)>eps:
        m=(a+b)/2
        if f(m)==0:
            return m
        if f(a)*f(m)<0 :
            b=m
        else :
            a=m
        cp+=1
    return m,cp

# %%
f=lambda x: x**3+x**2-3*x-3
dichow(-2,-1.5,f,0.001)
# Out:
# (-1.7314453125, 9)

# %% [markdown]
# --> On trouve la valeur de $α$ aprés 9 itérations

# %% [markdown]
# Le nombre des itérations est calculé par :
# $$N \geq E\left(\dfrac{\ln(b-a)-\ln(\varepsilon)}{\ln(2)}\right)$$
# avec $\varepsilon$ = $10^{-K}$

# %% [markdown]
# ## conclusion:
# c\'est une méthode très lente donc il faut avoir une autre méthode plus rapide qu\'on peut trouver dans l'exercice suivant:

# %% [markdown]
# ## Exercice N3:

# %% [markdown]
# ![ex3.png](attachment:ex3.png)

# %% [markdown]
# ## 1)

# %%
# %matplotlib inline

import numpy as np 
import matplotlib.pyplot as plt

f=lambda x:x**3+4*x**2-10

t=np.linspace(1,2,100)
plt.subplot(2,2,1)
plt.plot(t,f(t),'b')
plt.grid(True)
##########################################
t=np.linspace(1.2,1.4,100)
plt.subplot(2,2,2)
plt.plot(t,f(t),'b')
plt.grid(True)
##########################################
t=np.linspace(1.35,1.4,100)
plt.subplot(2,2,3)
plt.plot(t,f(t),'b')
plt.grid(True)
#########################################
t=np.linspace(1.365,1.367,100)
plt.subplot(2,2,4)
plt.plot(t,f(t),'b')
plt.grid(True)

# %% [markdown]
# ## 2)
# ### Justification théoriques pour g1, g2 et g3

# %% [markdown]
# a) $g(x)=\frac{1}{2}\sqrt{10-x^3}=x$.

# %% [markdown]
# $$x^3+4x^2-10=0$$
#
#  $$4x^2=10-x^3$$
#
#  $$2x=\sqrt{10-x^3}$$
#
#  $$x=\frac{1}{2}\sqrt{10-x^3}$$
#
# Donc $ f(x)=g(x)$

# %% [markdown]
# b) $g(x)=\sqrt{\displaystyle\frac{10}{4+x}}=x$.

# %% [markdown]
# $$x^3+4x^2-10=0$$
# $$x^3+4x^2=10$$
# $$x^2(x+4)=10$$
# $$x^2=\frac{10}{x+4}$$
# $$x=\sqrt{\displaystyle\frac{10}{4+x}}$$
# Donc $ f(x)=g(x)$

# %% [markdown]
# c) $g(x)=x-x^3-4x^2+10=x$.

# %% [markdown]
# $$x^3+4x^2-10=0$$
# $$x^3+4x^2-10+x-x=0$$
# $$x^3-4x^2+x-x=10$$
# $$x^3-4x^2+x=x+10$$
# $$4x^2+x=x-x^3+10$$
# $$x=x-x^3-4x^2+10$$
# Donc $ f(x)=g(x)$

# %% [markdown]
# ## 3)

# %%
import math
f=lambda x:  x**3+4*x**2-10 # la fonction f
g1=lambda x: 1/2*(math.sqrt(10-x**3))
g2=lambda x: math.sqrt(10/(x+4))
g3=lambda x: x-x**3-4*x**2 + 10


def ptfixe(g,x0,eps,nmax):
    zero=x0
    for i in range(nmax):
        x=zero 
        zero=g(x)
        erreur=abs(zero-x)
        print(zero)
        if erreur<eps:
            return zero,i
    print('pas de convergence avec le nombre d''iteration indique')

# %%
ptfixe(g1,1.5,0.001,50)
# Out:
# 1.286953767623375
# 1.4025408035395783
# 1.3454583740232942
# 1.3751702528160383
# 1.360094192761733
# 1.3678469675921328
# 1.3638870038840212
# 1.36591673339004
# 1.364878217193677
# 1.365410061169957
# (1.365410061169957, 9)

# %%
ptfixe(g2,1.5,0.001,50)
# Out:
# 1.348399724926484
# 1.3673763719912828
# 1.364957015402487
# 1.3652647481134421
# (1.3652647481134421, 3)

# %%
ptfixe(g3,1.5,0.001,5)
# Out:
# -0.875
# 6.732421875
# -469.72001200169325
# 102754555.18738511
# -1.0849338705317464e+24
# pas de convergence avec le nombre diteration indique

# %% [markdown]
# ## Conclusion:
# ### D'aprés ces résultats on constat que:
# <ul>
# <li>g1 converge</li>
# <li>g2 converge</li>
# <li>g3 diverge </li>
# <li>g2 est plus convergente que g1 puisque  g2 converge aprés 3 itérations seulement</li>
# </ul>

# %% [markdown]
# ## exercice N4:

# %% [markdown]
# ![ex4.png](attachment:ex4.png)
